# %%
import pandas as pd
import numpy as np

from glob import glob

import matplotlib.pyplot as plt
from PIL import Image

plt.style.use('ggplot')

# %%
img_fns = glob('img/*.jpg')

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(plt.imread(img_fns[0]))
ax.axis('off')
plt.show()

# %%
import keras_ocr

pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\rhayr\.keras-ocr\craft_mlt_25k.h5
# Downloading C:\Users\rhayr\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\rhayr\.keras-ocr\crnn_kurapan.h5
# Downloading C:\Users\rhayr\.keras-ocr\crnn_kurapan.h5

# %%
results = pipeline.recognize([img_fns[0]])

# %%
pd.DataFrame(results[0], columns=['text', 'bbox'])
# Out:
#            text                                               bbox
# 0   caterpillar  [[413.8658, 619.8104], [678.7254, 594.58575], ...
# 1      serialno  [[575.9761, 676.4597], [698.95557, 663.5146], ...
# 2        011919  [[557.8557, 700.8589], [674.2108, 686.005], [6...
# 3          type  [[347.13132, 705.03516], [416.73807, 698.406],...
# 4          3025  [[404.74225, 721.4903], [495.73737, 708.9393],...
# 5          msib  [[297.5282, 732.185], [394.5953, 723.3607], [3...
# 6            of  [[625.0, 732.8125], [656.25, 732.8125], [656.2...
# 7          list  [[573.3095, 740.77875], [623.18146, 736.245], ...
# 8    lubricants  [[570.8078, 763.4309], [705.40607, 741.65765],...
# 9   44751004121  [[299.5679, 799.4274], [543.57587, 763.2781], ...
# 10           no  [[348.20544, 771.11694], [397.24628, 766.2128]...
# 11           05  [[640.625, 770.3125], [679.6875, 770.3125], [6...
# 12         teml  [[571.0625, 784.9374], [635.37494, 775.7499], ...
# 13           no  [[420.2197, 820.9468], [459.9784, 816.97095], ...
# 14         part  [[349.78186, 833.7323], [417.9894, 820.94336],...
# 15         ltda  [[654.3375, 834.0126], [728.3125, 820.56256], ...
# 16       brasil  [[571.4306, 853.1352], [655.2927, 837.16156], ...
# 17      1542286  [[303.68033, 860.8264], [450.39954, 836.6828],...
# 18   automotive  [[393.08353, 886.2816], [566.99567, 853.26025]...
# 19   brasileira  [[546.095, 887.9323], [676.5525, 862.3067], [6...
# 20           zf  [[343.75, 889.0625], [387.5, 889.0625], [387.5...
# 21    industria  [[405.46292, 915.3734], [541.47174, 887.37164]...
# 22          sse  [[583.77405, 1036.0577], [683.2332, 1016.166],...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(plt.imread(img_fns[1]))
ax.axis('off')
plt.show()

# %%
results = pipeline.recognize([img_fns[1]])
pd.DataFrame(results[0], columns=['text', 'bbox'])
# Out:
#            text                                               bbox
# 0   caterpillar  [[626.0728, 329.3384], [1018.5791, 325.63544],...
# 1      serialno  [[860.47876, 437.45398], [1051.3434, 434.16324...
# 2          type  [[536.09204, 437.1038], [625.57855, 439.1849],...
# 3          msab  [[478.2824, 469.31085], [597.4687, 471.43918],...
# 4          8025  [[617.1875, 468.75], [739.0625, 468.75], [739....
# 5         19876  [[876.5624, 470.31244], [1018.7499, 470.31244]...
# 6            no  [[542.1875, 531.25], [596.875, 531.25], [596.8...
# 7          list  [[859.375, 534.375], [932.8125, 534.375], [932...
# 8            of  [[939.0625, 534.375], [985.9375, 534.375], [98...
# 9            sx  [[734.375, 564.0625], [787.5, 564.0625], [787....
# 10   lubricants  [[859.17664, 565.66943], [1073.3776, 563.7221]...
# 11         teml  [[859.375, 600.0], [959.375, 600.0], [959.375,...
# 12         part  [[546.875, 617.1875], [632.8125, 617.1875], [6...
# 13           no  [[640.625, 617.1875], [692.1875, 617.1875], [6...
# 14          alz  [[535.9375, 650.0], [626.5625, 650.0], [626.56...
# 15         ltda  [[1005.75055, 703.2735], [1124.7974, 701.14764...
# 16   automotive  [[609.375, 704.6875], [857.8125, 704.6875], [8...
# 17       brasil  [[868.75, 704.6875], [995.3125, 704.6875], [99...
# 18           zf  [[540.625, 706.25], [596.875, 706.25], [596.87...
# 19    industria  [[628.125, 750.0], [820.3125, 750.0], [820.312...
# 20   brasileira  [[831.2499, 750.0], [1037.4999, 750.0], [1037....

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(plt.imread(img_fns[2]))
ax.axis('off')
plt.show()

# %%
results = pipeline.recognize([img_fns[2]])
pd.DataFrame(results[0], columns=['text', 'bbox'])
# Out:
#            text                                               bbox
# 0   caterpillar  [[443.1751, 689.1915], [698.283, 685.2668], [6...
# 1      serialno  [[591.6499, 757.26056], [710.62213, 753.6554],...
# 2          type  [[368.25137, 765.7923], [435.8222, 763.6126], ...
# 3         01015  [[572.6103, 779.8713], [684.25714, 776.1498], ...
# 4          sozs  [[420.80078, 787.8407], [510.7588, 783.6566], ...
# 5          mseb  [[316.5979, 790.8623], [412.33978, 788.58264],...
# 6        listof  [[581.7655, 821.2801], [660.8264, 815.6328], [...
# 7            no  [[362.5, 831.25], [407.8125, 831.25], [407.812...
# 8    lubricants  [[579.9047, 840.00214], [709.2505, 831.0199], ...
# 9    fatsooniet  [[312.13977, 855.29297], [550.8761, 837.6088],...
# 10         teml  [[576.8719, 862.1431], [638.8326, 857.71735], ...
# 11           no  [[426.5625, 885.9375], [468.75, 885.9375], [46...
# 12         part  [[356.07794, 892.72473], [423.17767, 886.33435...
# 13      asa2z86  [[309.1792, 917.4154], [452.79153, 906.5357], ...
# 14         ltda  [[654.2852, 920.97766], [724.3657, 913.9697], ...
# 15       brasil  [[569.6096, 930.6081], [652.75946, 921.61896],...
# 16   automotive  [[391.6016, 949.63477], [564.8532, 931.6345], ...
# 17           zf  [[340.625, 951.5625], [385.9375, 951.5625], [3...
# 18   brasileira  [[541.0005, 965.0411], [670.7848, 947.9642], [...
# 19    industria  [[398.9423, 979.0385], [536.4423, 961.851], [5...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(plt.imread(img_fns[3]))
ax.axis('off')
plt.show()

# %%
results = pipeline.recognize([img_fns[3]])
pd.DataFrame(results[0], columns=['text', 'bbox'])
# Out:
#            text                                               bbox
# 0   caterpillar  [[307.54672, 551.6241], [746.7248, 549.211], [...
# 1      serialno  [[574.7647, 666.5302], [793.5536, 664.523], [7...
# 2          type  [[217.1875, 667.1875], [315.625, 667.1875], [3...
# 3          msab  [[160.9375, 701.5625], [310.9375, 701.5625], [...
# 4          bozs  [[304.6875, 701.5625], [443.75, 701.5625], [44...
# 5            no  [[232.8125, 762.5], [298.4375, 762.5], [298.43...
# 6          list  [[581.25, 768.75], [660.9375, 768.75], [660.93...
# 7            of  [[667.1875, 768.75], [718.75, 768.75], [718.75...
# 8             e  [[389.0625, 798.4375], [425.0, 798.4375], [425...
# 9          sizn  [[445.31244, 796.875], [529.68744, 796.875], [...
# 10   lubricants  [[582.8125, 800.0], [815.625, 800.0], [815.625...
# 11         teml  [[582.8125, 834.375], [692.1875, 834.375], [69...
# 12         part  [[248.4375, 850.0], [340.625, 850.0], [340.625...
# 13           no  [[350.0, 853.125], [412.5, 853.125], [412.5, 8...
# 14          aux  [[248.78244, 880.64233], [338.19418, 882.99524...
# 15           zf  [[250.0, 935.9375], [309.375, 935.9375], [309....
# 16   automotive  [[323.4375, 937.5], [585.9375, 937.5], [585.93...
# 17       brasil  [[600.1206, 938.6737], [736.3733, 940.67737], ...
# 18         ltda  [[748.4375, 940.625], [875.0, 940.625], [875.0...
# 19    industria  [[346.94434, 980.1163], [550.37524, 982.538], ...
# 20   brasileira  [[562.6756, 981.563], [781.77893, 985.18445], ...
